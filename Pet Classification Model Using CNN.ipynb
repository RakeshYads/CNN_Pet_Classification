# %% [markdown]
# # Pet Classification Model Using CNN

# %% [markdown]
# ### Project Objective:
# Building a CNN model that classifies the given pet images correctly into dog and cat images.
#
# To achieve the project objective: Will divide the project into 4 parts to have a better understandability and will follow below specifications to build CNN.
#
# #### Part-1: Importing required libraries for the project
# #### Part-2: Data Pre-processing
# #### Part-3: Building the CNN
# ● Input layer
# ● Convolutional layer 1 with 32 filters of kernel size[5,5]
# ● Pooling layer 1 with pool size[2,2] and stride 2
# ● Convolutional layer 2 with 64 filters of kernel size[5,5]
# ● Pooling layer 2 with pool size[2,2] and stride 2
# ● Dense layer whose output size is fixed in the hyper parameter: fc_size=32
# ● Dropout layer with dropout probability 0.4
#   Predict the class by doing a softmax on the output of the dropout layers.
# #### Part-4: Training and evaluation:
# ● For the training step, define the loss function and minimize it
# ● For the evaluation step, calculate the accuracy
#   Running the program for 100, 200, and 300 iterations, respectively. Following this by a report on the final accuracy and   loss on the evaluation data.

# %% [markdown]
# ## Part-1: Importing Libraries

# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.8.0'

# %% [markdown]
# ## Part-2: Data Pre-Processing

# %% [markdown]
# Preprocessing the Training Set

# %%
train_datagen = ImageDataGenerator(
                rescale = 1./255,
                #shear_range = 0.2,
                #zoom_range = 0.2,
                horizontal_flip = True)

training_set = train_datagen.flow_from_directory(
               'D:\\SimpliLearn\\DEEP_LEARNING\\Project\\data\\train',
                #target_size = (64,64),
                batch_size = 5,
                class_mode = 'binary')
# Out:
# Found 40 images belonging to 2 classes.

# %% [markdown]
# Preprocessing the Test Set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = train_datagen.flow_from_directory(
               'D:\\SimpliLearn\\DEEP_LEARNING\\Project\\data\\test',
                #target_size = (64,64),
                batch_size = 5,
                class_mode = 'binary')
# Out:
# Found 20 images belonging to 2 classes.

# %% [markdown]
# ## Part-3: Building the CNN

# %% [markdown]
# Initialize the Sequential

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# Adding the Input layer and 1st Convolution layer with 32 filters of kernel size of 5*5 matrix

# %%
#cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size = 5, activation = 'relu',input_shape = [64,64,3]))
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size = 5, activation = 'relu'))

# %% [markdown]
# Adding 1st Max Pooling layer with pool size of 2*2 matrix and stride 2

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size = 2,strides=2))

# %% [markdown]
# Adding 2nd Convolution layer with 64 filters of kernel size of 5*5 matrix

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size = 5, activation = 'relu'))

# %% [markdown]
# Adding 2nd Max Pooling layer with pool size of 2*2 matrix and stride 2

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size = 2,strides=2))

# %% [markdown]
# Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# Adding Fully Connected Layer

# %%
cnn.add(tf.keras.layers.Dense(units = 32,activation = 'relu'))

# %% [markdown]
# Adding Drop-Out Layer

# %%
cnn.add(tf.keras.layers.Dropout(.4))

# %% [markdown]
# Adding Output Layer

# %%
#Using Sigmoid Activation Function as this CNN falls in binary classification. Softmax will be used when we have One-Hot Encoding
cnn.add(tf.keras.layers.Dense(units = 1,activation = 'sigmoid'))

# %% [markdown]
# ## Part-4: Training and evaluation:

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0000001)
cnn.compile(optimizer = opt,loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# Training the Data with 100 epochs

# %%
cnn.fit(x=training_set,validation_data = test_set,epochs=100)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 8s 850ms/step - loss: 0.7313 - accuracy: 0.4250 - val_loss: 0.6857 - val_accuracy: 0.6000
# Epoch 2/100
# 8/8 [==============================] - 6s 817ms/step - loss: 0.7174 - accuracy: 0.3750 - val_loss: 0.6960 - val_accuracy: 0.5000
# Epoch 3/100
# 8/8 [==============================] - 6s 801ms/step - loss: 0.7072 - accuracy: 0.4750 - val_loss: 0.6928 - val_accuracy: 0.5500
# Epoch 4/100
# 8/8 [==============================] - 6s 803ms/step - loss: 0.6886 - accuracy: 0.5000 - val_loss: 0.6949 - val_accuracy: 0.5000
# Epoch 5/100
# 8/8 [==============================] - 6s 811ms/step - loss: 0.7085 - accuracy: 0.4500 - val_loss: 0.7012 - val_accuracy: 0.4500
# Epoch 6/100
# 8/8 [==============================] - 6s 796ms/step - loss: 0.6994 - accuracy: 0.5000 - val_loss: 0.6965 - val_accuracy: 0.5000
# Epoch 7/100
# ...

# %% [markdown]
# Training the Data with 200 epochs

# %%
cnn.fit(x=training_set,validation_data = test_set,epochs=200)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 7s 859ms/step - loss: 0.6702 - accuracy: 0.6500 - val_loss: 0.6963 - val_accuracy: 0.5000
# Epoch 2/200
# 8/8 [==============================] - 6s 820ms/step - loss: 0.6847 - accuracy: 0.4750 - val_loss: 0.7037 - val_accuracy: 0.4000
# Epoch 3/200
# 8/8 [==============================] - 6s 802ms/step - loss: 0.6849 - accuracy: 0.5750 - val_loss: 0.7073 - val_accuracy: 0.3500
# Epoch 4/200
# 8/8 [==============================] - 6s 801ms/step - loss: 0.6569 - accuracy: 0.6250 - val_loss: 0.7039 - val_accuracy: 0.5000
# Epoch 5/200
# 8/8 [==============================] - 6s 818ms/step - loss: 0.6821 - accuracy: 0.5500 - val_loss: 0.7003 - val_accuracy: 0.4000
# Epoch 6/200
# 8/8 [==============================] - 6s 810ms/step - loss: 0.6771 - accuracy: 0.5750 - val_loss: 0.7108 - val_accuracy: 0.4000
# Epoch 7/200
# ...

# %% [markdown]
# Training the Data with 300 epochs

# %%
cnn.fit(x=training_set,validation_data = test_set,epochs=300)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 7s 829ms/step - loss: 0.6649 - accuracy: 0.7250 - val_loss: 0.7107 - val_accuracy: 0.4500
# Epoch 2/300
# 8/8 [==============================] - 6s 798ms/step - loss: 0.6420 - accuracy: 0.6750 - val_loss: 0.7124 - val_accuracy: 0.4000
# Epoch 3/300
# 8/8 [==============================] - 6s 800ms/step - loss: 0.6697 - accuracy: 0.6500 - val_loss: 0.7086 - val_accuracy: 0.4000
# Epoch 4/300
# 8/8 [==============================] - 6s 804ms/step - loss: 0.6633 - accuracy: 0.7250 - val_loss: 0.7106 - val_accuracy: 0.3500
# Epoch 5/300
# 8/8 [==============================] - 6s 823ms/step - loss: 0.6509 - accuracy: 0.7000 - val_loss: 0.7021 - val_accuracy: 0.4500
# Epoch 6/300
# 8/8 [==============================] - 6s 805ms/step - loss: 0.6408 - accuracy: 0.7000 - val_loss: 0.7099 - val_accuracy: 0.4000
# Epoch 7/300
# ...

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, None, None, 32)    2432
#
#  max_pooling2d (MaxPooling2D  (None, None, None, 32)   0
#  )
#
#  conv2d_1 (Conv2D)           (None, None, None, 64)    51264
#
#  max_pooling2d_1 (MaxPooling  (None, None, None, 64)   0
#  2D)
#
#  flatten (Flatten)           (None, None)              0
#
#  dense (Dense)               (None, 32)                7620640
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# ...
# Total params: 7,674,369
# Trainable params: 7,674,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
cnn.evaluate(training_set)
# Out:
# 8/8 [==============================] - 2s 199ms/step - loss: 0.6108 - accuracy: 0.8500
# [0.6107755303382874, 0.8500000238418579]

# %%
cnn.evaluate(test_set)
# Out:
# 4/4 [==============================] - 1s 194ms/step - loss: 0.7144 - accuracy: 0.4500
# [0.7143951654434204, 0.44999998807907104]
